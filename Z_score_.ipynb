# %% [markdown]
# <a href="https://colab.research.google.com/github/TayyabKhan54/Machine-learning-project-/blob/main/Z_score_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import  pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataset= pd.read_csv("/content/bank_dataset_hello_filll.csv")
dataset.head(5)
# Out:
#   Customer_ID   Age Gender  Account_Balance   Account_Type  Credit_Score  \
# 0    CUST0001  56.0   Male          92751.0        Current         448.0
# 1    CUST0002  69.0   Male          28306.0        Savings         628.0
# 2    CUST0003  46.0   Male          86451.0  Fixed Deposit         455.0
# 3    CUST0004  32.0   Male          40915.0        Current         489.0
# 4    CUST0005  60.0   Male          38219.0        Current         793.0
#
#    Loan_Amount Loan_Status Branch_City  Tenure_Years
# 0      48515.0    Approved     Houston          23.0
# 1       5744.0    Approved    New York          14.0
# 2      18284.0    Rejected     Chicago           1.0
# 3      42417.0     Pending     Phoenix          18.0
# 4      39748.0    Rejected     Chicago          17.0

# %%
dataset.isnull().sum()
# Out:
# Customer_ID        1
# Age                2
# Gender             3
# Account_Balance    5
# Account_Type       4
# Credit_Score       2
# Loan_Amount        0
# Loan_Status        3
# Branch_City        3
# Tenure_Years       3
# dtype: int64

# %%
dataset.describe()
# Out:
#               Age  Account_Balance  Credit_Score   Loan_Amount  Tenure_Years
# count  698.000000       695.000000    698.000000    700.000000    697.000000
# mean    44.199140     49932.233094    583.647564  24573.345324     15.469154
# std     14.940404     27958.037887    155.494044  14047.207898      8.212304
# min     18.000000      1060.000000    300.000000    138.000000      1.000000
# 25%     32.000000     26745.000000    454.250000  12826.000000      9.000000
# 50%     45.000000     49302.000000    579.000000  24322.500000     15.000000
# 75%     56.000000     75250.000000    720.000000  36625.250000     22.000000
# max     69.000000     99875.000000    849.000000  49847.000000     29.000000

# %%
dataset.shape
# Out:
# (700, 10)

# %%
sns.boxplot(x="Loan_Amount",data=dataset)
# Out:
# <Axes: xlabel='Loan_Amount'>

# %%
sns.distplot(dataset["Loan_Amount"])
# Out:
# <Axes: xlabel='Loan_Amount', ylabel='Density'>

# %%
min_range =dataset["Loan_Amount"].mean()-(3*dataset["Loan_Amount"].std())

max_range=dataset["Loan_Amount"].mean()+(3*dataset["Loan_Amount"].std())

# %%
min_range,max_range
# Out:
# (np.float64(-17568.278371218894), np.float64(66714.96901864746))

# %%
new_data = dataset[dataset["Loan_Amount"]<=max_range]

# %%
sns.boxplot(x="Loan_Amount",data=dataset)
# Out:
# <Axes: xlabel='Loan_Amount'>

# %%
z_score= (dataset["Loan_Amount"] - dataset["Loan_Amount"]).mean()/dataset["Loan_Amount"].std()

# %%
dataset["z_score"]= z_score

# %%
dataset
# Out:
#     Customer_ID   Age  Gender  Account_Balance   Account_Type  Credit_Score  \
# 0      CUST0001  56.0    Male          92751.0        Current         448.0
# 1      CUST0002  69.0    Male          28306.0        Savings         628.0
# 2      CUST0003  46.0    Male          86451.0  Fixed Deposit         455.0
# 3      CUST0004  32.0    Male          40915.0        Current         489.0
# 4      CUST0005  60.0    Male          38219.0        Current         793.0
# ..          ...   ...     ...              ...            ...           ...
# 695    CUST0696  65.0  Female          29541.0        Savings         691.0
# 696    CUST0697  62.0  Female          80083.0  Fixed Deposit         739.0
# 697    CUST0698  18.0    Male          52027.0  Fixed Deposit         503.0
# 698    CUST0699  39.0    Male          35531.0        Savings         785.0
# 699    CUST0700  69.0    Male           9712.0  Fixed Deposit         330.0
#
#      Loan_Amount Loan_Status  Branch_City  Tenure_Years  z_score
# 0        48515.0    Approved      Houston          23.0      0.0
# 1         5744.0    Approved     New York          14.0      0.0
# 2        18284.0    Rejected      Chicago           1.0      0.0
# 3        42417.0     Pending      Phoenix          18.0      0.0
# 4        39748.0    Rejected      Chicago          17.0      0.0
# ..           ...         ...          ...           ...      ...
# 695      33467.0    Approved  Los Angeles          22.0      0.0
# 696      14534.0    Approved      Chicago          11.0      0.0
# 697      23854.0    Rejected     New York           2.0      0.0
# 698      42998.0     Pending      Houston          12.0      0.0
# 699      39065.0    Rejected      Houston          12.0      0.0
#
# [700 rows x 11 columns]

# %%
dataset[dataset["z_score"]<3]
# Out:
#     Customer_ID   Age  Gender  Account_Balance   Account_Type  Credit_Score  \
# 0      CUST0001  56.0    Male          92751.0        Current         448.0
# 1      CUST0002  69.0    Male          28306.0        Savings         628.0
# 2      CUST0003  46.0    Male          86451.0  Fixed Deposit         455.0
# 3      CUST0004  32.0    Male          40915.0        Current         489.0
# 4      CUST0005  60.0    Male          38219.0        Current         793.0
# ..          ...   ...     ...              ...            ...           ...
# 695    CUST0696  65.0  Female          29541.0        Savings         691.0
# 696    CUST0697  62.0  Female          80083.0  Fixed Deposit         739.0
# 697    CUST0698  18.0    Male          52027.0  Fixed Deposit         503.0
# 698    CUST0699  39.0    Male          35531.0        Savings         785.0
# 699    CUST0700  69.0    Male           9712.0  Fixed Deposit         330.0
#
#      Loan_Amount Loan_Status  Branch_City  Tenure_Years  z_score
# 0        48515.0    Approved      Houston          23.0      0.0
# 1         5744.0    Approved     New York          14.0      0.0
# 2        18284.0    Rejected      Chicago           1.0      0.0
# 3        42417.0     Pending      Phoenix          18.0      0.0
# 4        39748.0    Rejected      Chicago          17.0      0.0
# ..           ...         ...          ...           ...      ...
# 695      33467.0    Approved  Los Angeles          22.0      0.0
# 696      14534.0    Approved      Chicago          11.0      0.0
# 697      23854.0    Rejected     New York           2.0      0.0
# 698      42998.0     Pending      Houston          12.0      0.0
# 699      39065.0    Rejected      Houston          12.0      0.0
#
# [700 rows x 11 columns]
