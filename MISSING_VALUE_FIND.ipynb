# %% [markdown]
# <a href="https://colab.research.google.com/github/TayyabKhan54/Machine-learning-project-/blob/main/MISSING_VALUE_FIND.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# **import seaborn as sns** = that labriry dh chi pa hga bandi munga graph jorwale sho

# %% [markdown]
# **import matplotlib.pyplot as plt** = dh labriry munga ta plot jorii

# %%
import pandas as pd
dataset=pd.read_excel(r"/content/bank_dataset.xlsx")
dataset.head(5)
# Out:
#   Customer_ID   Age Gender  Account_Balance   Account_Type  Credit_Score  \
# 0    CUST0001  56.0   Male          92751.0        Current         448.0
# 1    CUST0002  69.0   Male          28306.0        Savings         628.0
# 2    CUST0003  46.0   Male          86451.0  Fixed Deposit         455.0
# 3    CUST0004  32.0   Male          40915.0        Current         489.0
# 4    CUST0005  60.0   Male          38219.0        Current         793.0
#
#    Loan_Amount Loan_Status Branch_City  Tenure_Years
# 0      48515.0    Approved     Houston          23.0
# 1       5744.0    Approved    New York          14.0
# 2      18284.0    Rejected     Chicago           1.0
# 3      42417.0     Pending     Phoenix          18.0
# 4      39748.0    Rejected     Chicago          17.0

# %% [markdown]
# kla chi pa excel form ki we nu bya ba waarser pd.read_excel likoo

# %%
dataset.shape
# Out:
# (700, 10)

# %% [markdown]
# shape mean dh di chi dh ba dh gorii chi pa di ki somra row aw column di

# %%
dataset.shape[0]
# Out:
# 700

# %% [markdown]
# mean chi 700 row di pa all execl sheet ki

# %%
dataset.isnull().sum().sum()
# Out:
# np.int64(31)

# %% [markdown]
# it mean chi pa di all dataset ki null value (31) di

# %%
(dataset.isnull().sum()/(dataset.shape[0]*dataset.shape[1]))*100
# Out:
# Customer_ID        0.014286
# Age                0.028571
# Gender             0.042857
# Account_Balance    0.071429
# Account_Type       0.057143
# Credit_Score       0.028571
# Loan_Amount        0.071429
# Loan_Status        0.042857
# Branch_City        0.042857
# Tenure_Years       0.042857
# dtype: float64

# %% [markdown]
# its mean chi dh all dataset ki 0 paracent null value dh.

# %%
dataset.isnull().sum()
# Out:
# Customer_ID        1
# Age                2
# Gender             3
# Account_Balance    5
# Account_Type       4
# Credit_Score       2
# Loan_Amount        5
# Loan_Status        3
# Branch_City        3
# Tenure_Years       3
# dtype: int64

# %% [markdown]
# (isnull) mean dh di chi pa di ki somra box empty di .

# %%
(dataset.isnull().sum()/dataset.shape[0])*100
# Out:
# Customer_ID        0.142857
# Age                0.285714
# Gender             0.428571
# Account_Balance    0.714286
# Account_Type       0.571429
# Credit_Score       0.285714
# Loan_Amount        0.714286
# Loan_Status        0.428571
# Branch_City        0.428571
# Tenure_Years       0.428571
# dtype: float64

# %% [markdown]
# (dataset.isnull().sum()/dataset.shape[0])*100 dh di mean dh di chi  dh empty box paracentage ba somra e .

# %%
dataset.notnull().sum()
# Out:
# Customer_ID        699
# Age                698
# Gender             697
# Account_Balance    695
# Account_Type       696
# Credit_Score       698
# Loan_Amount        695
# Loan_Status        697
# Branch_City        697
# Tenure_Years       697
# dtype: int64

# %% [markdown]
# dataset.notnull().sum() = its mean chi pa all dataset ki somra null value na di .

# %%
dataset.notnull().sum().sum()
# Out:
# np.int64(6969)

# %% [markdown]
# dataset.notnull().sum().sum() = its mean chi all dataset ki ba somra not null value e hga dh di (6969

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %% [markdown]
# dh ba munda ta graph khi chi somra paki null value di
