# %% [markdown]
# <a href="https://colab.research.google.com/github/TayyabKhan54/Machine-learning-project-/blob/main/missing_vlaue.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import  matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("/content/bank_dataset_hello_filll.csv")
dataset.head(5)
# Out:
#   Customer_ID   Age Gender  Account_Balance   Account_Type  Credit_Score  \
# 0    CUST0001  56.0   Male          92751.0        Current         448.0
# 1    CUST0002  69.0   Male          28306.0        Savings         628.0
# 2    CUST0003  46.0   Male          86451.0  Fixed Deposit         455.0
# 3    CUST0004  32.0   Male          40915.0        Current         489.0
# 4    CUST0005  60.0   Male          38219.0        Current         793.0
#
#    Loan_Amount Loan_Status Branch_City  Tenure_Years
# 0      48515.0    Approved     Houston          23.0
# 1       5744.0    Approved    New York          14.0
# 2      18284.0    Rejected     Chicago           1.0
# 3      42417.0     Pending     Phoenix          18.0
# 4      39748.0    Rejected     Chicago          17.0

# %%
dataset.shape
# Out:
# (700, 10)

# %%
dataset.isnull().sum()
# Out:
# Customer_ID     1
# Age             2
# Gender          3
# Account_Type    4
# Credit_Score    2
# Loan_Amount     0
# Loan_Status     3
# Branch_City     3
# Tenure_Years    3
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.drop(columns = ["Account_Balance"],inplace= True)

# %%
dataset.shape
# Out:
# (700, 9)

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.dropna(inplace=True)

# %%
dataset.isnull().sum()
# Out:
# Customer_ID     0
# Age             0
# Gender          0
# Account_Type    0
# Credit_Score    0
# Loan_Amount     0
# Loan_Status     0
# Branch_City     0
# Tenure_Years    0
# dtype: int64

# %%
sns.heatmap(dataset.isnull())
plt.show()

# %%
dataset.shape
# Out:
# (681, 9)

# %%
((700-681)/618)*100
# Out:
# 3.074433656957929
